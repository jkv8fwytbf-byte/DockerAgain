# %% [markdown]
# # 1. Python, tables and plots
#
# This is a **handout**. It lives in `shared/` (read-only). Copy it into `notebooks/` if you want to edit it.
#
# Run each cell with **Shift+Enter**.

# %% [markdown]
# ## Load the class scores
#
# The CSV is in the same shared folder as this notebook.

# %%
from pathlib import Path

import pandas as pd

candidates = [
    Path.home() / "shared" / "class-scores.csv",
    Path.cwd() / "class-scores.csv",
]
csv = next(p for p in candidates if p.is_file())
df = pd.read_csv(csv)
df.head()

# %% [markdown]
# ## Averages by group

# %%
summary = df.groupby("group")[["pretest", "project", "quiz"]].mean().round(1)
summary

# %% [markdown]
# ## Draw the project scores
#
# If a picture appears under the cell, matplotlib and seaborn are working.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
fig, ax = plt.subplots(figsize=(6, 3.2))
sns.barplot(data=df, x="name", y="project", hue="group", ax=ax)
ax.set_title("Project scores")
ax.set_xlabel("")
ax.set_ylabel("score")
plt.xticks(rotation=35, ha="right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Hand this in
#
# When you are done, copy the notebook into `submit/` and name it `week-1-yourname.ipynb`.
